# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot

# %% [markdown]
# # Demo reading data from AnalySim
#
# See more on [AnalySim](https://analysim-dev.herokuapp.com/home)

# %%
analysim_csv = pd.read_csv("https://neruosimhubstorage.blob.core.windows.net/project2/Folder1/AnalySim.csv")
analysim_csv
# Out:
#       simNo:int  simPar_EleakVal:decimal  simParPer_gBarP:int  \
# 0         50192                   -0.065                  150
# 1         87730                   -0.050                   25
# 2         90232                   -0.065                  150
# 3         91197                   -0.065                  175
# 4         95214                   -0.055                   50
# ...         ...                      ...                  ...
# 2112   10375932                   -0.065                   50
# 2113   10375933                   -0.060                   50
# 2114   10375934                   -0.055                   50
# 2115   10375935                   -0.050                   50
# 2116   10377914                   -0.055                  150
#
#       simParPer_gBarK2:int  simParPer_gBarLeak:int  simParPer_gBarSynS:int  \
# 0                      150                     100                      75
# ...

# %%
analysim_csv.plot("meanPeriod_L:decimal", "meanDutyCycle_L:decimal", kind = "scatter" )
